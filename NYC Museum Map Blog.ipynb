# %% [markdown]
# # NYC Museum Map Blog

# %% [markdown]
# ### Scrape data to get the full descriptions of each museum

# %%
# import beautifulsoup and set up link to scrape
import csv
import requests
import urllib.request
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/List_of_museums_in_New_York_City'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html, 'html.parser')

# %%
# metaphorically "throw net over" the content that we want.
rows = soup.findAll('tr')

# %%
# narrow down the details to get what we want
name = rows[4].td.text.strip('\n')
name
# Out:
# 'AIGA National Design Center'

# %%
# getting "focus" or category of museum
focus = rows[4].td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text.strip('\n').title()
focus
# Out:
# 'Design, Decorative Arts, Architecture'

# %%
# getting "summary" or description of museum
summary = rows[4].td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text.strip('\n').title()
summary
# Out:
# 'Website, Public Gallery Of The Aiga Dedicated To Presenting Examples Of Outstanding Contemporary Design'

# %%
#show progress bar when we scrape. use this!
from tqdm import tqdm

# %% [markdown]
# ### <i>After using code below, comment out to avoid running webscraper twice

# %% [markdown]
# ### ScrapeLoop through Wikipedia with codes we wrote above, save data to CSV

# %%
# file = open('nycmuseumdata.csv', 'w')
# writer = csv.writer(file)

# writer.writerow(['name', 'focus', 'summary'])

# for i in tqdm(range(2, len(rows))):
#     for row in rows:
#         try:
#             name = rows[i].td.text.strip('\n')
#             focus = rows[i].td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text.strip('\n').capitalize()
#             summary = rows[i].td.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.text.strip('\n').capitalize()
#         except:
#             pass
#     writer.writerow([name, focus, summary])

# %% [markdown]
# # Merge datasets (dataframe(df) with location + df with data)

# %%
#successfully scraped museum data with focus and summary details
df_data = pd.read_csv('nycmuseumdata.csv')
df_data.head(10)
# Out:
#                                       name  \
# 0                      9/11 Tribute Museum
# 1  African Burial Ground National Monument
# 2              AIGA National Design Center
# 3                           A.I.R. Gallery
# 4                       Alice Austen House
# 5     American Academy of Arts and Letters
# 6                 American Folk Art Museum
# 7       American Museum of Natural History
# 8       American Numismatic Society Museum
# 9                         Americas Society
#
#                                    focus  \
# 0                American and ny history
# 1           African and african-american
# 2  Design, decorative arts, architecture
# 3                       Contemporary art
# 4           Photography, film, new media
# 5                       Contemporary art
# 6                               Folk art
# 7                                 Nature
# 8                              Financial
# 9        Hispanic, latino, and caribbean
#
#                                              summary
# 0  History of the september 11 attacks and tours ...
# 1  Visitor center and memorial to an 18th-century...
# 2  Website, public gallery of the aiga dedicated ...
# 3                 Contemporary art by female artists
# 4  Home of photographer alice austen, also featur...
# 5  Exhibitions of its members in american literat...
# 6                                  American folk art
# 7  The world's largest natural history museum. in...
# 8  Exhibits of coins and medals from all periods ...
# 9  Exhibits of historic and contemporary art from...

# %%
# This is the other dataset with coordiantes from NYC gov
file = 'Museum Dataset.xlsx'
df_location = pd.read_excel(file) # plots df with coordinates/location details
df_location.head(3)
# Out:
#                                         the_geom  \
# 0  POINT (-74.01375579519738 40.703816216918035)
# 1  POINT (-74.06303178855111 40.615120837755356)
# 2  POINT (-73.94729768541572 40.833853500753314)
#
#                                    NAME             TEL  \
# 0  Alexander Hamilton U.S. Custom House  (212) 514-3700
# 1             Alice Austen House Museum  (718) 816-4506
# 2  American Academy of Arts and Letters  (212) 368-5900
#
#                                 URL           ADRESS1 ADDRESS2           CITY  \
# 0  http://www.oldnycustomhouse.gov/     1 Bowling Grn      NaN       New York
# 1       http://www.aliceausten.org/      2 Hylan Blvd      NaN  Staten Island
# 2    http://www.artsandletters.org/  633 W. 155th St.      NaN       New York
#
#      ZIP
# 0  10004
# 1  10305
# 2  10032

# %%
# let's lowercase our columns and add an underscore between words for easy access
## uneccessary but I like doing this for future convenience
df_location.columns = [x.lower() for x in df.columns] # show columns
df_location.columns = [x.replace(' ', '_').lower() for x in df_location.columns] #lower case and replace spaces with '_' for accessibility
df_location.columns
# Out:
# Index(['the_geom', 'name', 'tel', 'url', 'adress1', 'address2', 'city', 'zip'], dtype='object')

# %%
# clean up so that coordinates can be used - remove leading white space, remove the word POINT
df_location['the_geom'] = df_location['the_geom'].apply(lambda x: x.strip('POINT').lstrip().replace(' ', ', '))
df_location['the_geom']
# Out:
# 0      (-74.01375579519738, 40.703816216918035)
# 1      (-74.06303178855111, 40.615120837755356)
# 2      (-73.94729768541572, 40.833853500753314)
# 3       (-73.97810302110001, 40.76162497138548)
# 4        (-74.0396848374904, 40.69905626244391)
#                          ...
# 125     (-73.99388579658319, 40.73807723317813)
# 126     (-73.99379427245329, 40.73795994708654)
# 127    (-73.99392890421056, 40.738015384101416)
# 128       (-73.99381737049632, 40.738045683847)
# 129    (-73.99386877223978, 40.737986764588406)
# Name: the_geom, Length: 130, dtype: object

# %%
# merge "name" to get these two datasets together. Do an outer join to keep everything
df_final = df_location.merge(df_data, on='name', how='outer')
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306 entries, 0 to 305
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   the_geom  132 non-null    object
#  1   name      306 non-null    object
#  2   tel       130 non-null    object
#  3   url       132 non-null    object
#  4   adress1   132 non-null    object
#  5   address2  15 non-null     object
#  6   city      132 non-null    object
#  7   zip       132 non-null    float64
#  8   focus     181 non-null    object
#  9   summary   223 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 26.3+ KB

# %%
# take df_final to excel to fill in any missing data
## Some of the museums are spelled slightly different and could not be filled in properly. 
### I take it to excel to manually fill them in as there isn't too many.
df_final.to_excel('museum_cleaning.xlsx')

# %%
# now that I've filled in as much as I could, + 29 extra data points
df_final = pd.read_excel('museum_cleaning.xlsx').drop(columns='Unnamed: 0')
df_final.head()
# Out:
#                                    the_geom  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  (-74.01375579519738, 40.703816216918035)
#
#                                       name             tel  \
# 0                      9/11 Tribute Museum             NaN
# 1                           A.I.R. Gallery             NaN
# 2  African Burial Ground National Monument             NaN
# 3              AIGA National Design Center             NaN
# 4     Alexander Hamilton U.S. Custom House  (212) 514-3700
#
#                                 url        adress1 address2      city  \
# 0                               NaN            NaN      NaN       NaN
# 1                               NaN            NaN      NaN       NaN
# 2                               NaN            NaN      NaN       NaN
# 3                               NaN            NaN      NaN       NaN
# 4  http://www.oldnycustomhouse.gov/  1 Bowling Grn      NaN  New York
#
#        zip                                  focus  \
# 0      NaN                American and ny history
# 1      NaN                       Contemporary art
# 2      NaN           African and african-american
# 3      NaN  Design, decorative arts, architecture
# 4  10004.0                                    NaN
#
#                                              summary
# 0  History of the september 11 attacks and tours ...
# 1                 Contemporary art by female artists
# 2  Visitor center and memorial to an 18th-century...
# 3  Website, public gallery of the aiga dedicated ...
# 4                                                NaN

# %%
# so this is how much we have now... 79 full data rows. However, I want more.
df_final[(df_final['the_geom'].notna()) & (df_final['summary'].notna())].reset_index().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     79 non-null     int64
#  1   the_geom  79 non-null     object
#  2   name      79 non-null     object
#  3   tel       79 non-null     object
#  4   url       79 non-null     object
#  5   adress1   79 non-null     object
#  6   address2  8 non-null      object
#  7   city      79 non-null     object
#  8   zip       79 non-null     float64
#  9   focus     55 non-null     object
#  10  summary   79 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 6.9+ KB

# %%
# query the rows with coordinates and no summary, let's see what else we could do to supplement -
## ...ok since there's 50 more ... that's all folks. Let me know if there's a better way than googling each one!
### we'll plot the 79 that we have now.
df_final[(df_final['the_geom'].notna()) & (df_final['summary'].isna())].reset_index()
# Out:
#     index                                  the_geom  \
# 0       4  (-74.01375579519738, 40.703816216918035)
# 1       8    (-74.0396848374904, 40.69905626244391)
# 2       9  (-73.99392890421056, 40.738015384101416)
# 3      12   (-73.99388579658319, 40.73807723317813)
# 4      20   (-73.94654590494326, 40.83358228246046)
# 5      30   (-73.87974874003561, 40.87823644134894)
# 6      34   (-73.94401601383748, 40.67450699609931)
# 7      44   (-74.00731553374261, 40.74789760206738)
# 8      46   (-73.97727391968168, 40.78587092106756)
# 9      53   (-73.93173408706043, 40.86492363574811)
# 10     60   (-73.97304190142106, 40.76210697296256)
# 11     63  (-74.00613537578622, 40.747894926234274)
# 12     64   (-73.94649318169672, 40.83330210970132)
# 13     65  (-73.98731863959442, 40.757501085511855)
# 14     68   (-73.99272306225821, 40.72495970416682)
# 15     91   (-73.96174204015233, 40.77916564085246)
# 16    107   (-73.89098784384107, 40.87835786499017)
# 17    109   (-74.01808694309555, 40.67557193487433)
# 18    114   (-73.93765514503832, 40.76695661305254)
# 19    115  (-73.99749410687575, 40.719194628210495)
# 20    116   (-74.00664185516354, 40.72335066225381)
# 21    120  (-73.94694494514727, 40.850220034849166)
# 22    125   (-74.00965483733572, 40.75233019732761)
# 23    130   (-73.93514567999574, 40.74396007246262)
# 24    131   (-73.98618833058292, 40.74719709497243)
# 25    134   (-73.99376449363902, 40.73802754297413)
# 26    147   (-73.97988117952895, 40.75078436678353)
# 27    152   (-73.98132148561602, 40.74929507249673)
# 28    157   (-73.97499987035063, 40.75824830530754)
# 29    160   (-73.92822391104288, 40.74634173827231)
# 30    164   (-73.98272584235525, 40.77025240986238)
# 31    166    (-73.99670247583494, 40.7247979456424)
# 32    167   (-73.97442477664784, 40.68524514383062)
# 33    179   (-74.07373713057605, 40.64094901557986)
# 34    180  (-74.01372704598201, 40.704321256986034)
# 35    189   (-74.00811754401903, 40.70347829082743)
# 36    192   (-73.97425753844574, 40.77927324139346)
# 37    196   (-73.9791241123914, 40.752422920262084)
# 38    206   (-73.94621241792795, 40.74583946863492)
# 39    211   (-73.89314845618621, 40.76460725545623)
# 40    216   (-73.97257491067647, 40.78285983221266)
# 41    219   (-73.9799105035754, 40.765012313344094)
# 42    224   (-73.98224232560065, 40.73875919099525)
# 43    229   (-73.95891102040586, 40.78300947618501)
# 44    230    (-73.9735078210536, 40.76147030101873)
# 45    237  (-73.98967904824913, 40.718687698398995)
# 46    240  (-73.98501448982452, 40.719616728018636)
# 47    241    (-73.9380587417615, 40.80527638435791)
# 48    242   (-73.94196177006319, 40.66891157732498)
# 49    245   (-73.99392966775832, 40.74700837582729)
# 50    266   (-73.99379427245329, 40.73795994708654)
#
#                                                  name             tel  \
# 0                Alexander Hamilton U.S. Custom House  (212) 514-3700
# 1                 American Immigration History Center  (212) 363-3200
# 2                  American Jewish Historical Society  (212) 294-6160
# 3      American Sephardi Federation / Sephardic House  (212) 294-8350
# 4                                     Audubon Terrace             NaN
# 5                    Bronx Historical Society & Musem  (718) 881-8900
# 6                          Brooklyn Children's Museum  (718) 735-4400
# 7                                  Chelsea Art Museum  (212) 255-0719
# 8                      Children's Museum of Manhattan  (212) 721-1234
# 9                                           Cloisters  (212) 923-3700
# 10                                      Dahesh Museum  (212) 759-0606
# 11                                 Dia Art Foundation  (212) 989 5566
# 12                        Dia at the Hispanic Society  (845) 440-0100
# 13                  Discovery Times Square Exposition  (866) 987-9692
# 14                       East Village History Project  (212) 614-8702
# 15                           Goethe-Institut New York  (212) 439-8700
# 16                  Holocaust Museum & Studies Center  (718) 817-7700
# 17        Hudson Waterfront Museum and Showboat Barge  (718) 624-4719
# 18                        Isamu Noguchi Garden Museum  (718) 204-7088
# 19                            Italian American Museum  (212) 965-9000
# 20                             Jackie Robinson Museum  (212) 290-8600
# 21  Jeffrey's Hook lighthouse (Little Red Lighthouse)  (212) 304-2365
# 22                            John J. Harvey Fireboat             NaN
# 23                      LaGuardia and Wagner Archives  (718) 482-5065
# 24             Lee Young Hee Museum of Korean Culture  (212) 560-0722
# 25                                Leo Baeck Institute  (212) 744-6400
# 26             Mexican Cultural Institute of New York  (212) 217-6422
# 27                          Morgan Library and Museum  (212) 685-0008
# 28                              Municipal Art Society  (212) 935-3960
# 29                             Museum for African Art  (718) 784-7700
# 30                             Museum of Biblical Art  (212) 408-1200
# 31            Museum of Comic and Cartoon Art (MoCCA)  (212) 254 3511
# 32  Museum of Contemporary African Diasporan Arts ...  (718) 230-0492
# 33                         National Lighthouse Museum  (718) 556-1681
# 34             National Museum of the American Indian  (212) 514-3700
# 35                        New York City Police Museum  (212) 480-3100
# 36                        New York Historical Society  (212) 873-3400
# 37                          New York Tolerance Center  (212) 697-1180
# 38                     P.S. 1 Contemporary Art Center  (718) 784-2084
# 39        Queens Art Museum - Bulova Corporate Center  (516) 624-1910
# 40  Rose Center for Earth and Space (Hayden Planet...  (212) 769-5100
# 41                       Rose Museum at Carnegie Hall  (212) 903-9629
# 42                       School of Visual Arts Museum  (212) 592-2145
# 43                       Solomon R. Guggenheim Museum  (212) 423-3500
# 44                         Sony Wonder Technology Lab  (212) 833-8100
# 45                                    Tenement Museum  (212) 431-0233
# 46                    The Freakatorium, El Museo Loco  (212) 375-0475
# 47                          The Jazz Museum in Harlem  (212) 348-8300
# 48                       The Jewish Children's Museum  (718) 467-0600
# 49                                  The Museum at FIT  (212) 217-5800
# 50                 YIVO Institute for Jewish Research  (212) 246-6860
#
#                                                   url  \
# 0                    http://www.oldnycustomhouse.gov/
# 1                         http://www.ellisisland.org/
# 2                                http://www.ajhs.org/
# 3          http://www.americansephardifederation.org/
# 4   http://www.washington-heights.us/history/archi...
# 5              http://www.bronxhistoricalsociety.org/
# 6                        http://www.brooklynkids.org/
# 7                    http://www.chelseaartmuseum.org/
# 8                                http://www.cmom.org/
# 9                 http://www.metmuseum.org/cloisters/
# 10                        http://www.daheshmuseum.org
# 11                          http://www.diacenter.org/
# 12                          http://www.diabeacon.org/
# 13                   http://www.discoverytsx.com/nyc/
# 14                                  http://leshp.org/
# 15        http://www.goethe.de/ins/us/ney/deindex.htm
# 16                   http://www.holocauststudies.org/
# 17                   http://www.waterfrontmuseum.org/
# 18                            http://www.noguchi.org/
# 19              http://www.italianamericanmuseum.org/
# 20                     http://www.jackierobinson.org/
# 21  http://www.nycgovparks.org/sub_about/parks_div...
# 22                           http://www.fireboat.org/
# 23  http://www.laguardiawagnerarchive.lagcc.cuny.e...
# 24                              http://www.lyhkm.org/
# 25                                http://www.lbi.org/
# 26                          http://www.lavitrina.com/
# 27                  http://www.themorgan.org/home.asp
# 28                                    http://mas.org/
# 29                         http://www.africanart.org/
# 30                              http://www.mobia.org/
# 31                            http://www.moccany.org/
# 32                             http://www.mocada.org/
# 33   http://statenislandusa.com/pages/lighthouse.html
# 34                            http://www.nmai.si.edu/
# 35                    http://www.nycpolicemuseum.org/
# 36                     https://www.nyhistory.org/web/
# 37  http://www.kintera.org/site/pp.asp?c=fwLYKnN8L...
# 38                                http://www.ps1.org/
# 39                   http://www.bdg.net/properties/1/
# 40         http://www.haydenplanetarium.org/index.php
# 41  http://www.carnegiehall.org/textSite/the_basic...
# 42  http://www.schoolofvisualarts.edu/sa/index.jsp...
# 43                         http://www.guggenheim.org/
# 44                     http://wondertechlab.sony.com/
# 45                           http://www.tenement.org/
# 46                       http://www.freakatorium.com/
# 47                 http://www.jazzmuseuminharlem.org/
# 48                          http://www.jcmonline.org/
# 49                      http://www.fitnyc.edu/306.asp
# 50                      http://www.yivoinstitute.org/
#
#                              adress1  \
# 0                      1 Bowling Grn
# 1                       Ellis Island
# 2                     15 W. 16th St.
# 3                     15 W. 16th St.
# 4             Broadway at 155 Street
# 5                3309 Bainbridge Ave
# 6                145 Brooklyn Avenue
# 7               556 West 22nd Street
# 8               212 West 83rd Street
# 9           99 Margaret Corbin Drive
# 10                580 Madison Avenue
# 11                 535 W 22nd Street
# 12             613 West 155th Street
# 13                     226 W 44th St
# 14                        308 Bowery
# 15                 1014 Fifth Avenue
# 16                     75 W 205th St
# 17                   290 Conover St.
# 18            32-37 Vernon Boulevard
# 19                  155 Mulberry St.
# 20                   1 Hudson Square
# 21  178th Street at the Hudson River
# 22       Pier 66 at West 26th Street
# 23                31-10 Thomson Ave.
# 24                2 West 32nd Street
# 25                    15 W. 16th St.
# 26                    27 E. 39th St.
# 27                225 Madison Avenue
# 28                457 Madison Avenue
# 29                 36-01 43rd Avenue
# 30                     1865 Broadway
# 31                      594 Broadway
# 32                   80 Hanson Place
# 33                1 Lighthouse Plaza
# 34                   1 Bowling Green
# 35                      100 Old Slip
# 36                2 West 77th Street
# 37                      50 E 42nd St
# 38                22-25 Jackson Ave.
# 39               75-20 Astoria Blvd.
# 40               15 West 81st Street
# 41              154 West 57th Street
# 42                   209 E. 23rd St.
# 43                 1071 Fifth Avenue
# 44                   550 Madison Ave
# 45                108 Orchard Street
# 46                    57 Clinton St.
# 47               104 E. 126th Street
# 48                  792 Eastern Pkwy
# 49    7th Avenue at West 27th Street
# 50                    15 W. 16th St.
#
#                                              address2              city  \
# 0                                                 NaN          New York
# 1                                                 NaN          New York
# 2                                                 NaN          New York
# 3                                                 NaN          New York
# 4                                                 NaN          New York
# 5                                                 NaN             Bronx
# 6                                                 NaN          Brooklyn
# 7                                                 NaN          New York
# 8                                                 NaN          New York
# 9                                                 NaN          New York
# 10                                                NaN          New York
# 11                                                NaN          New York
# 12                                                NaN          New York
# 13                                                NaN          New York
# 14                                                NaN          New York
# 15                                                NaN          New York
# 16                                                NaN             Bronx
# 17                                                NaN          Brooklyn
# 18                                                NaN  Long Island City
# 19                                                NaN          New York
# 20                         75 Varick Street 2nd Floor          New York
# 21                                                NaN          New York
# 22                                                NaN          New York
# 23  Fiorello H. LaGuardia Community College/CUNY R...            Queens
# 24                                          Suite 301          New York
# 25                                                NaN          New York
# 26                                                NaN          New York
# 27                                                NaN          New York
# 28                                                NaN          New York
# 29                                          3rd Floor            Queens
# 30                                                NaN          New York
# 31                                          Suite 401          New York
# 32                                                NaN          Brooklyn
# 33                                                NaN     Staten Island
# 34                                                NaN          New York
# 35                                                NaN          New York
# 36                                                NaN          New York
# 37                                                NaN          New York
# 38                                                NaN            Queens
# 39                                                NaN   Jackson Heights
# 40                                                NaN          New York
# 41                                                NaN          New York
# 42                                                NaN          New York
# 43                                                NaN          New York
# 44                                         Sony Plaza          New York
# 45                                                NaN          New York
# 46                                                NaN          New York
# 47                                           Suite 2D          New York
# 48                                                NaN          Brooklyn
# 49                                                NaN          New York
# 50                                                NaN          New York
#
#         zip             focus summary
# 0   10004.0               NaN     NaN
# 1       0.0               NaN     NaN
# 2   10011.0               NaN     NaN
# 3   10011.0               NaN     NaN
# 4   10032.0               NaN     NaN
# 5   10467.0               NaN     NaN
# 6   11213.0               NaN     NaN
# 7   10011.0               NaN     NaN
# 8   10024.0               NaN     NaN
# 9   10040.0               NaN     NaN
# 10  10022.0               NaN     NaN
# 11  10011.0  Contemporary art     NaN
# 12  10032.0               NaN     NaN
# 13   1036.0               NaN     NaN
# 14  10012.0               NaN     NaN
# 15  10028.0               NaN     NaN
# 16  10468.0               NaN     NaN
# 17  11231.0               NaN     NaN
# 18  11106.0               NaN     NaN
# 19  10013.0               NaN     NaN
# 20  10013.0               NaN     NaN
# 21  10033.0               NaN     NaN
# 22  10001.0               NaN     NaN
# 23  11101.0               NaN     NaN
# 24  10001.0               NaN     NaN
# 25  10011.0               NaN     NaN
# 26  10016.0               NaN     NaN
# 27  10016.0               NaN     NaN
# 28  10022.0               NaN     NaN
# 29  11101.0               NaN     NaN
# 30  10023.0               NaN     NaN
# 31  10012.0               NaN     NaN
# 32  11217.0               NaN     NaN
# 33  10301.0               NaN     NaN
# 34  10004.0               NaN     NaN
# 35  10038.0               NaN     NaN
# 36  10024.0               NaN     NaN
# 37  10017.0               NaN     NaN
# 38  11101.0               NaN     NaN
# 39  11386.0               NaN     NaN
# 40  10024.0               NaN     NaN
# 41      0.0               NaN     NaN
# 42  10010.0               NaN     NaN
# 43  10128.0               NaN     NaN
# 44  10022.0               NaN     NaN
# 45  10002.0               NaN     NaN
# 46  10002.0               NaN     NaN
# 47  10035.0               NaN     NaN
# 48  11213.0               NaN     NaN
# 49  10001.0               NaN     NaN
# 50  10011.0               NaN     NaN

# %% [markdown]
# ##### save current final dataframe into csv or xlsx for Tableau to read, comment out when done

# %%
# df_final.to_csv('final_museum.csv')
